# %%
import os
import openai

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.getenv('OPENAI_API_KEY')
print("OpenAI API Key: ",openai.api_key)
# Out:
# OpenAI API Key:  sk-proj-mTOBlqD81G30AFcPsmToT3BlbkFJFpBYYpF3RHv1QYtlmqTm

# %%
def get_completion_from_messages(messages, model="gpt-3.5-turbo-0125", temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
#     print(str(response.choices[0].message))
    return response.choices[0].message["content"]

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context) 
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, style={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display 

# import requests
# from bs4 import BeautifulSoup

# def fetch_web_content(url):
#     response = requests.get(url)
#     if response.status_code == 200:
#         return response.text
#     else:
#         return None

# def extract_text_from_html(html_content):
#     soup = BeautifulSoup(html_content, 'html.parser')
#     text = soup.get_text()
#     lines = text.splitlines()
#     non_empty_lines = [line for line in lines if line.strip()]
#     return '\n'.join(non_empty_lines)


# # Example usage
# urls = ["https://www.evertecinc.com/en/",
#         "https://www.evertecinc.com/en/pos/",
#         "https://www.evertecinc.com/en/smart-terminals/",
#         "https://www.evertecinc.com/en/ecommerce-gateway/",
#         ]
# htmls=[]
# for u in urls:
#     new_html = fetch_web_content(u)
#     htmls.append(new_html)

# wts=[]
# for h in htmls:
#     new_wt = extract_text_from_html(h)
#     wts.append(new_wt)

# prods = [{
#     "category":"Merchants",
#     "group":"Payment Acceptance",
#     "subgroup":"N/A",
#     "product":"ATH Business",
# },
# {
#     "category":"Merchants",
#     "group":"Payment Acceptance",
#     "subgroup":"Smart terminals",
#     "product":"",
# },
# {
#     "category":"Merchants",
#     "group":"Payment Acceptance",
#     "subgroup":"Digital payments",
#     "product":"",
# },
# {
#     "category":"Merchants",
#     "group":"Payment Acceptance",
#     "subgroup":"N/A",
#     "product":"ATH Business",
# }]


context = [ {'role':'system', 'content':f"""
1. Your name is Evertito, and you are an Artificial \
Intelligence-driven Sales Consultant that offers merchants solutions from a catalogue\
based on what a business owner (that will be the user) is\
looking for. First, you will greet, present yourself and then\
assist the user. You work for Evertec, Inc. a leading \
electronic transactions and technology company with \
headquarters in San Juan, Puerto Rico. The company operates\
in 26 countries in Latin America and the Caribbean,\
providing services in three key areas: merchant acquiring,\
payment processing, and business solutions, so you will \
strictly suggest Evertec products in Payment Acceptance. \
You will be nice, patient,polite, honest and harmless to the user. 


2. Based on the input provided by the user,(which will be me this time),\
your task is to offer reasonable and logical solutions related to merchant solutions. \
Your role will be understanding users needs, offer the best product solution, compare and \
suggest best suitable product for the user. Be brief and clear in your responses. And last but not least,\
if:
    - a user is interested in acquiring a product.
    - user asks what is the next step 
    - user wants to contact support.
you will nicely ask for user’s name, email and phone number, and then write a report of the conversation \
inferring user’s need, solution you offered and user accepted, and user’s contact information (name, email, phone) \
in a format I will give you. This report will be sent to a sales representative so it can be contacted.  
Also, infer if the user emotions and be honest of how you think the user feels with the solution you gave,\
ask how the user feels about the solution. If user seems confused and doubtful, respectfully ask the reason\
why. Be subtle.
             
             
3. Use this format when structuring conversation’s report:

Contact information: 
    Name: User’s name
    
    Email: User’s email
    
    Phone: User’s phone number (999)-999-999 format.
    
User needs: 
    Describe the users needs  in a precise and brief way
    
I suggested: 
    Mention the solution you offered that the user accepted
    
My feedback: 
    Infer user’s emotion about the solution you offered.

    
4. Here is an example of what a report can look like:
Contact Information: 
    Name: Diego
        
    Email: diego.laboy1@upr.edu
        
    Phone: (787)-456-1234
User needs: 
    A system to handle sales transactions. Think of it as a digital cash register.
    
I suggested: 
    a Point of Sale system from Evertec.
    
My feedback: 
    Diego seems very convinced that this solution will fulfill the needs for his business.

"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4ae3d831-8e2e-4368-b849-574b56af2798'>
#   <div id="ac3af4ff-35f4-4ae7-8004-2ea2963cd7f0" data-root-id="4ae3d831-8e2e-4368-b849-574b56af2798" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
